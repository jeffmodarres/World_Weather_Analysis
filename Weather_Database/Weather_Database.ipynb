# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
len(coordinates)
# Out:
# 2000

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
# (cities)

# %%
# Run an API request for each of the cities.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Create counters.
record_count = 1
set_count = 1
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    try:
            # Create endpoint URL with each city.
        city_url = url + "&q=" + city.replace(" ","+")

        # Log the URL, record, and set numbers and the city.
        print(f"Processing Record {record_count} of Set {set_count} | {city}")
        # Add 1 to the record count.
        record_count += 1
        # Parse the JSON and retrieve data.
        print(city_url)
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather description":city_weather_description,
                          "Country": city_country,                          
                          "Date": city_date})
                            

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=longyearbyen
# Processing Record 2 of Set 1 | blackwater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=blackwater
# Processing Record 3 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=albany
# Processing Record 4 of Set 1 | bull savanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bull+savanna
# Processing Record 5 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=busselton
# Processing Record 6 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=cape+town
# Processing Record 7 of Set 1 | tunduru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tunduru
# City not found. Skipping...
# Processing Record 8 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bredasdorp
# Processing Record 9 of Set 1 | doctor pedro p. pena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=doctor+pedro+p.+pena
# City not found. Skipping...
# Processing Record 10 of Set 1 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=marzuq
# Processing Record 11 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kavieng
# Processing Record 12 of Set 1 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=avera
# Processing Record 13 of Set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 1 | zalantun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=zalantun
# Processing Record 15 of Set 1 | fort morgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=fort+morgan
# Processing Record 16 of Set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=belushya+guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=waipawa
# Processing Record 18 of Set 1 | morant bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=morant+bay
# Processing Record 19 of Set 1 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ostrovnoy
# Processing Record 20 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=punta+arenas
# Processing Record 21 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=hermanus
# Processing Record 22 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=hilo
# Processing Record 23 of Set 1 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=amapa
# Processing Record 24 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=georgetown
# Processing Record 25 of Set 1 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=leningradskiy
# Processing Record 26 of Set 1 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nishihara
# Processing Record 27 of Set 1 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 1 | nouna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nouna
# Processing Record 29 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mahebourg
# Processing Record 30 of Set 1 | krasnoarmeysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=krasnoarmeysk
# Processing Record 31 of Set 1 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=beloha
# Processing Record 32 of Set 1 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=dikson
# Processing Record 34 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=chokurdakh
# Processing Record 35 of Set 1 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=yerbogachen
# Processing Record 36 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=yellowknife
# Processing Record 37 of Set 1 | akyab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=akyab
# Processing Record 38 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=cidreira
# Processing Record 39 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=rikitea
# Processing Record 40 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mataura
# Processing Record 41 of Set 1 | teguise
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=teguise
# Processing Record 42 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=atuona
# Processing Record 43 of Set 1 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=east+london
# Processing Record 44 of Set 1 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bathsheba
# Processing Record 45 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ushuaia
# Processing Record 46 of Set 1 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=rocha
# Processing Record 47 of Set 1 | sergeyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sergeyevka
# Processing Record 48 of Set 1 | gibsons
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=gibsons
# Processing Record 49 of Set 1 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=san+cristobal
# Processing Record 50 of Set 1 | zapolyarnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=zapolyarnyy
# Processing Record 1 of Set 2 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=alofi
# Processing Record 2 of Set 2 | nanzhang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nanzhang
# Processing Record 3 of Set 2 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sao+joao+da+barra
# Processing Record 4 of Set 2 | libourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=libourne
# Processing Record 5 of Set 2 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 2 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=vila+franca+do+campo
# Processing Record 7 of Set 2 | hunza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=hunza
# City not found. Skipping...
# Processing Record 8 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tasiilaq
# Processing Record 9 of Set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bengkulu
# Processing Record 10 of Set 2 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bambous+virieux
# Processing Record 11 of Set 2 | yangshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=yangshan
# Processing Record 12 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=upernavik
# Processing Record 13 of Set 2 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=port+elizabeth
# Processing Record 14 of Set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=vaini
# Processing Record 15 of Set 2 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=caravelas
# Processing Record 16 of Set 2 | khanpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=khanpur
# Processing Record 17 of Set 2 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=beringovskiy
# Processing Record 18 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=luderitz
# Processing Record 19 of Set 2 | sao francisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sao+francisco
# Processing Record 20 of Set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=puerto+ayora
# Processing Record 21 of Set 2 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=the+valley
# Processing Record 22 of Set 2 | chunskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=chunskiy
# Processing Record 23 of Set 2 | padang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=padang
# Processing Record 24 of Set 2 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=san+patricio
# Processing Record 25 of Set 2 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=oranjemund
# Processing Record 26 of Set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=arraial+do+cabo
# Processing Record 27 of Set 2 | samarkand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=samarkand
# Processing Record 28 of Set 2 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kavaratti
# Processing Record 29 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=victoria
# Processing Record 30 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=torbay
# Processing Record 31 of Set 2 | aksay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=aksay
# Processing Record 32 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tuktoyaktuk
# Processing Record 33 of Set 2 | tungor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tungor
# Processing Record 34 of Set 2 | sosnovo-ozerskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sosnovo-ozerskoye
# Processing Record 35 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=jamestown
# Processing Record 36 of Set 2 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=coihaique
# Processing Record 37 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mar+del+plata
# Processing Record 38 of Set 2 | san ignacio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=san+ignacio
# Processing Record 39 of Set 2 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sao+filipe
# Processing Record 40 of Set 2 | payson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=payson
# Processing Record 41 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=port+alfred
# Processing Record 42 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bethel
# Processing Record 43 of Set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=barrow
# Processing Record 44 of Set 2 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=port+hedland
# Processing Record 45 of Set 2 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=itarema
# Processing Record 46 of Set 2 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ribeira+grande
# Processing Record 47 of Set 2 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mount+gambier
# Processing Record 48 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 2 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=prince+rupert
# Processing Record 50 of Set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 3 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=hobart
# Processing Record 2 of Set 3 | koumac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=koumac
# Processing Record 3 of Set 3 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=port+blair
# Processing Record 4 of Set 3 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=erenhot
# Processing Record 5 of Set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nikolskoye
# Processing Record 6 of Set 3 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=lorengau
# Processing Record 7 of Set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=lompoc
# Processing Record 8 of Set 3 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=westport
# Processing Record 9 of Set 3 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 3 | seymchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=seymchan
# Processing Record 11 of Set 3 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=yar-sale
# Processing Record 12 of Set 3 | brindisi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=brindisi
# Processing Record 13 of Set 3 | shubarshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=shubarshi
# Processing Record 14 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=souillac
# Processing Record 15 of Set 3 | ribeira do pombal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ribeira+do+pombal
# Processing Record 16 of Set 3 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=pacific+grove
# Processing Record 17 of Set 3 | anapskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=anapskaya
# Processing Record 18 of Set 3 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=dicabisagan
# Processing Record 19 of Set 3 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=necochea
# Processing Record 20 of Set 3 | jijiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=jijiga
# Processing Record 21 of Set 3 | beni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=beni
# Processing Record 22 of Set 3 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bluff
# Processing Record 23 of Set 3 | zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=zhangye
# Processing Record 24 of Set 3 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=isangel
# Processing Record 25 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=new+norfolk
# Processing Record 26 of Set 3 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=saldanha
# Processing Record 27 of Set 3 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=pevek
# Processing Record 28 of Set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kaitangata
# Processing Record 29 of Set 3 | talas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=talas
# Processing Record 30 of Set 3 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=vardo
# Processing Record 31 of Set 3 | chaman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=chaman
# Processing Record 32 of Set 3 | ban nahin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ban+nahin
# Processing Record 33 of Set 3 | tatarskaya pishlya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tatarskaya+pishlya
# Processing Record 34 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=lebu
# Processing Record 35 of Set 3 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=te+anau
# Processing Record 36 of Set 3 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=iqaluit
# Processing Record 37 of Set 3 | saint james
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=saint+james
# Processing Record 38 of Set 3 | phuthaditjhaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=phuthaditjhaba
# Processing Record 39 of Set 3 | pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=pangkalanbuun
# Processing Record 40 of Set 3 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=saint+anthony
# Processing Record 41 of Set 3 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=naze
# Processing Record 42 of Set 3 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=gizo
# Processing Record 43 of Set 3 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kapaa
# Processing Record 44 of Set 3 | katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=katobu
# Processing Record 45 of Set 3 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=acapulco
# Processing Record 46 of Set 3 | barbar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=barbar
# City not found. Skipping...
# Processing Record 47 of Set 3 | barpeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=barpeta
# Processing Record 48 of Set 3 | alexandria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=alexandria
# Processing Record 49 of Set 3 | lodwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=lodwar
# Processing Record 50 of Set 3 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mecca
# Processing Record 1 of Set 4 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=san+policarpo
# Processing Record 2 of Set 4 | lumphat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=lumphat
# Processing Record 3 of Set 4 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kodiak
# Processing Record 4 of Set 4 | grand centre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=grand+centre
# City not found. Skipping...
# Processing Record 5 of Set 4 | rio claro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=rio+claro
# Processing Record 6 of Set 4 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=grand+river+south+east
# City not found. Skipping...
# Processing Record 7 of Set 4 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=pitimbu
# Processing Record 8 of Set 4 | mandawar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mandawar
# Processing Record 9 of Set 4 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=faya
# Processing Record 10 of Set 4 | kinanah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kinanah
# City not found. Skipping...
# Processing Record 11 of Set 4 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=rio+grande
# Processing Record 12 of Set 4 | swan hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=swan+hill
# Processing Record 13 of Set 4 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=vanavara
# Processing Record 14 of Set 4 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sabang
# Processing Record 15 of Set 4 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=amderma
# City not found. Skipping...
# Processing Record 16 of Set 4 | fukuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=fukuma
# Processing Record 17 of Set 4 | poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=poya
# Processing Record 18 of Set 4 | puerto colombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=puerto+colombia
# Processing Record 19 of Set 4 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=castro
# Processing Record 20 of Set 4 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=san+quintin
# Processing Record 21 of Set 4 | verkhnechusovskiye gorodki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=verkhnechusovskiye+gorodki
# Processing Record 22 of Set 4 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=los+llanos+de+aridane
# Processing Record 23 of Set 4 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=butaritari
# Processing Record 24 of Set 4 | jambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=jambi
# Processing Record 25 of Set 4 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=saint-philippe
# Processing Record 26 of Set 4 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=adrar
# Processing Record 27 of Set 4 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sobolevo
# Processing Record 28 of Set 4 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=qaanaaq
# Processing Record 29 of Set 4 | qingdao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=qingdao
# Processing Record 30 of Set 4 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=berlevag
# Processing Record 31 of Set 4 | moerai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=moerai
# Processing Record 32 of Set 4 | mapiripan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mapiripan
# Processing Record 33 of Set 4 | tabou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tabou
# Processing Record 34 of Set 4 | loudi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=loudi
# Processing Record 35 of Set 4 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=petropavlovsk-kamchatskiy
# Processing Record 36 of Set 4 | biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=biak
# Processing Record 37 of Set 4 | diffa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=diffa
# Processing Record 38 of Set 4 | kashan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kashan
# Processing Record 39 of Set 4 | kungsbacka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kungsbacka
# Processing Record 40 of Set 4 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=carnarvon
# Processing Record 41 of Set 4 | sinop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sinop
# Processing Record 42 of Set 4 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=katsuura
# Processing Record 43 of Set 4 | kegayli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kegayli
# City not found. Skipping...
# Processing Record 44 of Set 4 | fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=fukue
# Processing Record 45 of Set 4 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=banda+aceh
# Processing Record 46 of Set 4 | nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nabire
# Processing Record 47 of Set 4 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=thompson
# Processing Record 48 of Set 4 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=salalah
# Processing Record 49 of Set 4 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ketchikan
# Processing Record 50 of Set 4 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=vostok
# Processing Record 1 of Set 5 | inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=inirida
# Processing Record 2 of Set 5 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tiksi
# Processing Record 3 of Set 5 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=saint+george
# Processing Record 4 of Set 5 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=lata
# Processing Record 5 of Set 5 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 5 | atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=atasu
# Processing Record 7 of Set 5 | sherlovaya gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sherlovaya+gora
# Processing Record 8 of Set 5 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=namibe
# Processing Record 9 of Set 5 | jimani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=jimani
# Processing Record 10 of Set 5 | horsham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=horsham
# Processing Record 11 of Set 5 | wuda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=wuda
# Processing Record 12 of Set 5 | kilmez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kilmez
# City not found. Skipping...
# Processing Record 13 of Set 5 | burkhala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=burkhala
# City not found. Skipping...
# Processing Record 14 of Set 5 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=pisco
# Processing Record 15 of Set 5 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=chuy
# Processing Record 16 of Set 5 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tevaitoa
# Processing Record 17 of Set 5 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=narsaq
# Processing Record 18 of Set 5 | campina verde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=campina+verde
# Processing Record 19 of Set 5 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=provideniya
# Processing Record 20 of Set 5 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=yulara
# Processing Record 21 of Set 5 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=severo-yeniseyskiy
# Processing Record 22 of Set 5 | kalabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kalabo
# Processing Record 23 of Set 5 | mookane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mookane
# Processing Record 24 of Set 5 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=dingle
# Processing Record 25 of Set 5 | nador
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nador
# Processing Record 26 of Set 5 | todos santos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=todos+santos
# Processing Record 27 of Set 5 | kaseda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kaseda
# Processing Record 28 of Set 5 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=talnakh
# Processing Record 29 of Set 5 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=cherskiy
# Processing Record 30 of Set 5 | maryville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=maryville
# Processing Record 31 of Set 5 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=hualmay
# Processing Record 32 of Set 5 | coolum beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=coolum+beach
# Processing Record 33 of Set 5 | akim swedru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=akim+swedru
# Processing Record 34 of Set 5 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=richards+bay
# Processing Record 35 of Set 5 | ola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ola
# Processing Record 36 of Set 5 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=baykit
# Processing Record 37 of Set 5 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=avarua
# Processing Record 38 of Set 5 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=hasaki
# Processing Record 39 of Set 5 | havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=havoysund
# Processing Record 40 of Set 5 | porto torres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=porto+torres
# Processing Record 41 of Set 5 | muisne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=muisne
# Processing Record 42 of Set 5 | nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nago
# Processing Record 43 of Set 5 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=klaksvik
# Processing Record 44 of Set 5 | marabba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=marabba
# Processing Record 45 of Set 5 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=norman+wells
# Processing Record 46 of Set 5 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=alice+springs
# Processing Record 47 of Set 5 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=cabo+san+lucas
# Processing Record 48 of Set 5 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=geraldton
# Processing Record 49 of Set 5 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 5 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=viedma
# Processing Record 1 of Set 6 | barawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=barawe
# City not found. Skipping...
# Processing Record 2 of Set 6 | martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=martapura
# Processing Record 3 of Set 6 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=cockburn+town
# Processing Record 4 of Set 6 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ponta+do+sol
# Processing Record 5 of Set 6 | trud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=trud
# Processing Record 6 of Set 6 | kuah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kuah
# Processing Record 7 of Set 6 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=port+lincoln
# Processing Record 8 of Set 6 | tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tual
# Processing Record 9 of Set 6 | puerto baquerizo moreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=puerto+baquerizo+moreno
# Processing Record 10 of Set 6 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=flin+flon
# Processing Record 11 of Set 6 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ilulissat
# Processing Record 12 of Set 6 | solsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=solsvik
# City not found. Skipping...
# Processing Record 13 of Set 6 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=fairbanks
# Processing Record 14 of Set 6 | micheweni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=micheweni
# Processing Record 15 of Set 6 | fredericksburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=fredericksburg
# Processing Record 16 of Set 6 | yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=yatou
# Processing Record 17 of Set 6 | eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=eyl
# Processing Record 18 of Set 6 | bondoukou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bondoukou
# Processing Record 19 of Set 6 | teguldet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=teguldet
# Processing Record 20 of Set 6 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=haines+junction
# Processing Record 21 of Set 6 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mys+shmidta
# City not found. Skipping...
# Processing Record 22 of Set 6 | bayanday
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bayanday
# Processing Record 23 of Set 6 | aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=aksarka
# Processing Record 24 of Set 6 | little current
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=little+current
# Processing Record 25 of Set 6 | yunhe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=yunhe
# Processing Record 26 of Set 6 | zaria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=zaria
# Processing Record 27 of Set 6 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 6 | nueve de julio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nueve+de+julio
# Processing Record 29 of Set 6 | beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=beyneu
# Processing Record 30 of Set 6 | kayerkan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kayerkan
# Processing Record 31 of Set 6 | marsala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=marsala
# Processing Record 32 of Set 6 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=honningsvag
# Processing Record 33 of Set 6 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sept-iles
# Processing Record 34 of Set 6 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=labuhan
# Processing Record 35 of Set 6 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=esperance
# Processing Record 36 of Set 6 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=codrington
# Processing Record 37 of Set 6 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=deputatskiy
# Processing Record 38 of Set 6 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=fortuna
# Processing Record 39 of Set 6 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=dwarka
# Processing Record 40 of Set 6 | den helder
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=den+helder
# Processing Record 41 of Set 6 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=hofn
# Processing Record 42 of Set 6 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=khatanga
# Processing Record 43 of Set 6 | magoula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=magoula
# Processing Record 44 of Set 6 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=lavrentiya
# Processing Record 45 of Set 6 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=margate
# Processing Record 46 of Set 6 | jesus carranza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=jesus+carranza
# Processing Record 47 of Set 6 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=khasan
# Processing Record 48 of Set 6 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=roald
# Processing Record 49 of Set 6 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=harper
# Processing Record 50 of Set 6 | wulanhaote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 7 | sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sampit
# Processing Record 2 of Set 7 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=moron
# Processing Record 3 of Set 7 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=gigmoto
# Processing Record 4 of Set 7 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=comodoro+rivadavia
# Processing Record 5 of Set 7 | koboldo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=koboldo
# City not found. Skipping...
# Processing Record 6 of Set 7 | craig
# ...
# Processing Record 13 of Set 14 | baoqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=baoqing
# Processing Record 14 of Set 14 | sturgeon falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sturgeon+falls
# Processing Record 15 of Set 14 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=makakilo+city
# Processing Record 16 of Set 14 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=goderich
# Processing Record 17 of Set 14 | garowe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=garowe
# Processing Record 18 of Set 14 | ruda slaska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ruda+slaska
# Processing Record 19 of Set 14 | steamboat springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=steamboat+springs
# Processing Record 20 of Set 14 | auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=auki
# Processing Record 21 of Set 14 | lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=lethem
# Processing Record 22 of Set 14 | armacao dos buzios
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=armacao+dos+buzios
# City not found. Skipping...
# Processing Record 23 of Set 14 | lapi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=lapi
# Processing Record 24 of Set 14 | sao gabriel da cachoeira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sao+gabriel+da+cachoeira
# Processing Record 25 of Set 14 | mmabatho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mmabatho
# Processing Record 26 of Set 14 | tygda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tygda
# Processing Record 27 of Set 14 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=arman
# Processing Record 28 of Set 14 | chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=chumikan
# Processing Record 29 of Set 14 | nyakahanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nyakahanga
# Processing Record 30 of Set 14 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=gamba
# Processing Record 31 of Set 14 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ahipara
# Processing Record 32 of Set 14 | iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=iquique
# Processing Record 33 of Set 14 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=along
# Processing Record 34 of Set 14 | quisqueya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=quisqueya
# Processing Record 35 of Set 14 | krasnokamensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=krasnokamensk
# Processing Record 36 of Set 14 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=olafsvik
# Processing Record 37 of Set 14 | shaunavon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=shaunavon
# Processing Record 38 of Set 14 | bombay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bombay
# Processing Record 39 of Set 14 | hongjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=hongjiang
# Processing Record 40 of Set 14 | uyovu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=uyovu
# Processing Record 41 of Set 14 | morrope
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=morrope
# Processing Record 42 of Set 14 | esmeraldas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=esmeraldas
# Processing Record 43 of Set 14 | at-bashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=at-bashi
# Processing Record 44 of Set 14 | loandjili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=loandjili
# Processing Record 45 of Set 14 | areosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=areosa
# Processing Record 46 of Set 14 | benjamin constant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=benjamin+constant
# Processing Record 47 of Set 14 | yakeshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=yakeshi
# Processing Record 48 of Set 14 | burgeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=burgeo
# Processing Record 49 of Set 14 | ladario
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ladario
# Processing Record 50 of Set 14 | ust-kamchatsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 15 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kahului
# Processing Record 2 of Set 15 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=havelock
# Processing Record 3 of Set 15 | bhatkal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=bhatkal
# Processing Record 4 of Set 15 | baikunthpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=baikunthpur
# Processing Record 5 of Set 15 | archidona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=archidona
# Processing Record 6 of Set 15 | eshowe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=eshowe
# Processing Record 7 of Set 15 | kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kenora
# Processing Record 8 of Set 15 | ketou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ketou
# Processing Record 9 of Set 15 | moses lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=moses+lake
# Processing Record 10 of Set 15 | rincon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=rincon
# Processing Record 11 of Set 15 | great bend
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=great+bend
# Processing Record 12 of Set 15 | miles city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=miles+city
# Processing Record 13 of Set 15 | devyatka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=devyatka
# City not found. Skipping...
# Processing Record 14 of Set 15 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=komsomolskiy
# Processing Record 15 of Set 15 | brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=brae
# Processing Record 16 of Set 15 | sungaipenuh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sungaipenuh
# Processing Record 17 of Set 15 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=alyangula
# Processing Record 18 of Set 15 | mosetse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mosetse
# Processing Record 19 of Set 15 | pemba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=pemba
# Processing Record 20 of Set 15 | searcy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=searcy
# Processing Record 21 of Set 15 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=salinopolis
# Processing Record 22 of Set 15 | ngukurr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 15 | kozachi laheri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kozachi+laheri
# Processing Record 24 of Set 15 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=shimoda
# Processing Record 25 of Set 15 | alpharetta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=alpharetta
# Processing Record 26 of Set 15 | zaranj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=zaranj
# Processing Record 27 of Set 15 | diapaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=diapaga
# Processing Record 28 of Set 15 | mindelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mindelo
# Processing Record 29 of Set 15 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=umm+kaddadah
# Processing Record 30 of Set 15 | ust-omchug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=ust-omchug
# Processing Record 31 of Set 15 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kirakira
# Processing Record 32 of Set 15 | luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=luganville
# Processing Record 33 of Set 15 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tomatlan
# Processing Record 34 of Set 15 | tabursuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tabursuq
# Processing Record 35 of Set 15 | vulcan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=vulcan
# Processing Record 36 of Set 15 | rumoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=rumoi
# Processing Record 37 of Set 15 | palauig
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=palauig
# Processing Record 38 of Set 15 | zamora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=zamora
# Processing Record 39 of Set 15 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=praia
# Processing Record 40 of Set 15 | champasak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=champasak
# Processing Record 41 of Set 15 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=sola
# Processing Record 42 of Set 15 | chabahar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=chabahar
# Processing Record 43 of Set 15 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=halalo
# City not found. Skipping...
# Processing Record 44 of Set 15 | saint-vallier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=saint-vallier
# Processing Record 45 of Set 15 | chimala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=chimala
# Processing Record 46 of Set 15 | pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=pochutla
# Processing Record 47 of Set 15 | litoral del san juan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=litoral+del+san+juan
# City not found. Skipping...
# Processing Record 48 of Set 15 | strezhevoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=strezhevoy
# Processing Record 49 of Set 15 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=nome
# Processing Record 50 of Set 15 | yankton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=yankton
# Processing Record 1 of Set 16 | khash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=khash
# Processing Record 2 of Set 16 | kuryk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=kuryk
# Processing Record 3 of Set 16 | tangping
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=tangping
# Processing Record 4 of Set 16 | alto araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=alto+araguaia
# Processing Record 5 of Set 16 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=asau
# Processing Record 6 of Set 16 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=batticaloa
# Processing Record 7 of Set 16 | balclutha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=balclutha
# Processing Record 8 of Set 16 | puerto carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=puerto+carreno
# Processing Record 9 of Set 16 | shahr-e babak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=shahr-e+babak
# Processing Record 10 of Set 16 | guerrero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=guerrero
# Processing Record 11 of Set 16 | takaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=takaka
# Processing Record 12 of Set 16 | mahonda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=mahonda
# Processing Record 13 of Set 16 | yizheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d3166461e354a81efaa2810f5e286a03&q=yizheng
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
len(cities)
# Out:
# 763

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
